# %% [markdown]
# #1
# #23
# #456
# #78910##

# %%
n = int(input())
i = 1
while i <= n:
    j = 1
    p = i
    while j <= i:
        print(p, end="")
        j = j + 1
        p = p + 1
    print()
    i = i + 1
# Out:
# 1
# 23
# 345
